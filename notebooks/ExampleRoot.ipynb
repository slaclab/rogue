# %% [markdown]
# Here we first start a server fro the ExampleRoot class.
#
# The server script will be started in an xterm. Please note the port number provided in the console.

# %%
import os

os.system("xterm -e 'python -m pyrogue.examples' &")
# Out:
# 0
# xterm: cannot load font "-misc-fixed-medium-r-semicondensed--13-120-75-75-c-60-iso10646-1"

# %% [markdown]
# Here we start the GUI using another xterm from a system call, please make sure the port number matches as noted above.

# %%
os.system("xterm -e 'python -m pyrogue gui --server localhost:9099' &")
# Out:
# 0
# xterm: cannot load font "-misc-fixed-medium-r-semicondensed--13-120-75-75-c-60-iso10646-1"

# %% [markdown]
# We can now interact with the running server using a virtual client. Again please note the port number from above.

# %%
import pyrogue.interfaces
client = pyrogue.interfaces.VirtualClient(addr='localhost', port=9099)
root = client.root

root.LocalTime.get()
# Out:
# Connected to ExampleRoot at localhost:9099
# '2022-03-25 13:45:05 PDT'

# %% [markdown]
# Now we get a plot created in the Rogue server.

# %%
# %matplotlib inline
root.TestPlotFigure.get()
# Out:
# WARNING:pyrogue.VirtualClient.VirtualClient:I have not heard from ExampleRoot in 10 seconds. It may be busy, continuing to wait...
